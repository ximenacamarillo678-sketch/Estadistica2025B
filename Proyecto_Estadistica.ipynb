# %% [markdown]
# <a href="https://colab.research.google.com/github/ximenacamarillo678-sketch/Estadistica2025B/blob/main/Proyecto_Estadistica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto de Estadistica Primera unidad

# %% [markdown]
# INTRODUCCION

# %% [markdown]
# El bienestar de la felicidad de las naciones son temas de gran relevancia, ya que se entiende mucho el hecho de comprender el desarrollo humano, esto va más allá de los indicadores económicos el World happiness report 2015 hace que se recopila la información en donde esta información sea de distintos países y regiones, siempre considerando los factores en el establecidos más adelante se desarrollará el código dicho elementos en el cual pondremos un mapa de calor en el cual recuperar toda la información adecuada, dando así los códigos correctos y los resultados que en este engloba así como los factores de la economía en global, lo de la salud, la familia, la libertad y la confianza. Todo esto en las instituciones este análisis se hizo con el propósito de buscar el hecho de explorar que las variables se relacionan de manera más significativa con el índice de felicidad, y como estas diferencias se manifiestan entre países y regiones más adelante se desenvolverán de una manera específica, dando así el tema explícito, teniendo losresultados estadísticos posteriormente analizando cada uno de los puntos, dando así los gráficos, además de el código en general que se vio con toda esta información englobada, siendo así uno de los principales herramientas para generarlo, poniendo en práctica todo lo he visto en clases y desarrollado de una manera explícita y entendible.

# %% [markdown]
# Hipótesis

# %% [markdown]
# Se va opinando que los países con mayor producto interno bruto, mejore la esperanza de vida y de una mayor libertad a las políticas y así tienden a mostrar niveles más altos de felicidad en comparación con aquellos menores indicadores que son socioeconómicos en dicho país

# %% [markdown]
# Marco teórico

# %% [markdown]
# Este estudio y este análisis que se hizo aproximadamente la felicidad nacional, se enmarca en las teorías del desarrollo humano y la economía del bienestar, todo esto según la ONU, ya que la felicidad no depende únicamente de la riqueza, sino también de los factores sociales, culturales y políticos. Estas investigaciones previas han demostrado que la confianza en el gobierno, además de la calidad de vida y metiendo mucho el hecho del capital social, la percepción de justicia influyen mucho y directamente en el bienestar subjetivo dicho reporte del cual se sacó el código para hacer este trabajo, se ha consolidado como una herramienta internacional para comparar y entender estas dinámicas, integrando así las dimensiones, económicas, sociales de salud y psicológicas, que es la percepción de la libertad de la generosidad que se llega a tener

# %% [markdown]
# Metodologia

# %% [markdown]
# Algunas herramientas utilizadas fue Python ya que como su lenguaje es de programación pandas para la carga limpieza y en eso la la intervención de la manipulación de datos, así como para la visualización, en este caso que fueron el mapa de calor y los gráficos de depresión donde se llevaron ciertos procedimientos, ya que se cargó el dataset en un archivo CSV
# Ya que se realizaron las primeras filas, en eso se incluyó mucho la revisión igual de las variables disponibles para así, nosotros familia izarnos con la estructura de los datos en eso se relaciona análisis descriptivo de las variables principales, metiendo los promedios, los rangos y en eso englobando la distribución, posteriormente elaborando un mapa de calor de correlaciones entre las variables numéricas se metió mucho la economía a la salud, la familia, la libertad, la confianza y la generosidad y en esto englobando el índice de felicidad, así construyeron gráficos de dos variables, que es la economía vs la felicidad y la salud vs la felicidad así se compararon los resultados que vamos teniendo a nivel de regiones geográficas para observar nosotros los patrones globales, y así dando un criterio de análisis que se buscaba determinar qué factores muestran con mayor la relación de nivel de la felicidad y así, por último, observando la posición relativa de los países en el rankingy comprando los valores de las variables explicativas

# %% [markdown]
# Resultados:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load data from the correct URL (assuming 'worldometer_data.csv' contains the necessary columns)
df = pd.read_csv("https://raw.githubusercontent.com/ximenacamarillo678-sketch/Estadistica2025B/refs/heads/main/2015.csv")

# The following lines are commented out as they are not needed
# import pandas as pt
# df=pt.read_csv("https://raw.githubusercontent.com/ximenacamarillo678-sketch/Estadistica2025B/refs/heads/main/2015.csv")
# df


# Convert 'gender' from text to numbers (assuming 'gender' column exists and has these values)
# Note: This part might still cause an error if 'gender' or 'grade_level' columns are not in worldometer_data.csv
# We may need to inspect the data after loading to confirm column names and values.
# df["gender"] = df["gender"].map({
#     "Male": 1,
#     "Female": 2,
#     "Other": 3
# })

# Convert 'grade_level' to numbers (assuming 'grade_level' column exists)
# df["grade_level"] = df["grade_level"].map({
#     9: 1,
#     10: 2,
#     11: 3,
#     12: 4
# })

# --- Crear matriz de correlaciones ---
# The correlation matrix and heatmap will only include numeric columns present in the loaded data.
corr = df.corr(numeric_only=True)

# --- Dibujar mapa de calor ---
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Mapa de calor de correlaciones", fontsize=14)
plt.show()

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#X=gender
#y=math_score

#1.Establesca una variable dependiente ( Y ) y una variable independiente ( X ).
x = df["Happiness Rank"]
y = df["Economy (GDP per Capita)"]

#2. grafico de dispersion
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8), dpi=49)
plt.scatter(x, y, label="Desempeño", color="blue", s=60)
plt.xlabel("Happiness Rank", fontsize= 20)
plt.ylabel("Economy (GDP per Capita)", fontsize= 20)
plt.title("Grafico de dispersión", color= "orange", fontsize= 30)
plt.gca().spines[["top","right"]].set_visible(False)
plt.grid()
plt.legend()

#3.¿Los datos soportan la suposición de linealidad? no soporto la linealidad

#4.Calcule el coeficiente de correlación e interprete el resultado.
Sxx=((x - x.mean())**2).sum()
print(Sxx)
Syy=((y - y.mean())**2).sum()
print(Syy)
Sxy=((x - x.mean())*(y-y.mean())).sum()
print(Sxy)
from math import sqrt
r= Sxy/sqrt(Sxx*Syy)
print("coeficiente de correlacion=", round(r,4))
# print("coeficiente de correlacion (forma facil)=", df.corr())
from scipy.stats import pearsonr
print("coeficiente de correlacion", pearsonr(x,y))
# "~" significa depende de ejemplo x~y
#r= coeficiente de correlacion


#5 Calcule el coeficiente de determinación e interprete el resultado.
#print(r**2)
#r= pearsonr(x,y)
#print(r)


print(r**2)
print("coeficiente de determinación:",r**2)


#6.Obtenga la recta de regresión ajustada y grafíquelo sobre el gráfico de
#dispersión.

import statsmodels.api as sm
x_constante=sm.add_constant(x)
x
x_constante
modelo=sm.OLS(y,x_constante).fit()
modelo.params
#respuesta y=24.53 + 0.643x
print("parametros:", modelo.params)
yc=modelo.predict(x_constante)
plt.plot(x, yc, color="black", linestyle="--", linewidth=2, alpha=0.5)
plt.show()

from sklearn.metrics import r2_score
r2=r2_score(y,yc)
print("\nCoeficiente de determinacion=", round(r2,4))

#7
intervalo_de_confianza=modelo.conf_int(alpha=0.05)
intervalo_de_confianza

print("\n intervalo de confianza:", intervalo_de_confianza)

#8
import matplotlib.pyplot as plt
residuales=modelo.resid
plt.figure(figsize=(16,8), dpi=49)
plt.scatter(x,residuales, label="Desempeño", color="blue",s=60)
plt.xlabel("Happiness Rank", fontsize=20)
plt.ylabel("Economy (GDP per Capita)", fontsize=20)
plt.title("Grafico de Residuales", fontsize=30,)
plt.gca().spines[["top","right"]].set_visible(False)
plt.grid()
plt.legend()

plt.axhline(y=0,color="gray", linestyle="--")
plt.show()



#el test de shapiro es para menores de 30 y el test de breusch pagan para mas de
#30

#9.tes de shapiro
#H0: hay normalidad
#Hi: no hay normalidad
# sig.: 0.05

from scipy.stats import shapiro
estadistico_shapiro, valor_p_shapiro= shapiro(residuales)
print("valor_p(shapiro)= ", valor_p_shapiro)

#hay normalidad, no se rechaza hipotesis nula


#10.tes de breusch-pagan
#H0: hay homocedasticidad
#Hi: no hay homocedasticidad
#sig.: 0.05

from statsmodels.stats.api import het_breuschpagan
_, valor_p_bp, _, _ = het_breuschpagan(residuales, x_constante)
print(f'valor_p de Breusch-Pagan: {valor_p_bp:0.4f}\n')

#hay homocedasticidad, por lo tanto no se rechaza la hipotesis nula

#11
#interpolar: esta dentro del rango de X y debe haber correlacion
#extrapolar: es que esta fuera del rengo de X y debe de cumplir con todos los
#supuestos (usar con precausion)

print("x=2", modelo.predict([1,2]))
print("x=7", modelo.predict([1,7]))

   #supuestos: linealidad, homocedasticidad, normalidad ( estos ultimos 2 son
   #residuales)


#12
#Ho= B1=0
#H1 (diferente) B1
df["x"]=x
df["y"]=y
print("\nUltimo paso")
from statsmodels.formula.api import ols
modelo_lineal=ols("y~x", data=df).fit()
tabla_anova=sm.stats.anova_lm(modelo_lineal)
tabla_anova
# Out:
# 328673.4936708861
# 25.51349884797468
# -2273.96958278481
# coeficiente de correlacion= -0.7853
# coeficiente de correlacion PearsonRResult(statistic=np.float64(-0.7852669153290175), pvalue=np.float64(2.684956442772621e-34))
# 0.6166441283103503
# coeficiente de determinación: 0.6166441283103503
# parametros: const             1.396124
# Happiness Rank   -0.006919
# dtype: float64
# Coeficiente de determinacion= 0.6166
#
#  intervalo de confianza:                        0         1
# const           1.317057  1.475192
# Happiness Rank -0.007781 -0.006056
# valor_p(shapiro)=  0.9882535902004257
# valor_p de Breusch-Pagan: 0.0136
#
# x=2 [1.38228708]
# x=7 [1.34769394]
#
# Ultimo paso
#              df     sum_sq    mean_sq           F        PR(>F)
# x           1.0  15.732749  15.732749  250.932596  2.684956e-34
# Residual  156.0   9.780750   0.062697         NaN           NaN

# %% [markdown]
# Conclusion

# %% [markdown]
# El anterior archivo y análisis nos permitió identificar que la felicidad de los países no depende únicamente de factores económicos, sino también de elementos sociales, políticos y culturales al terminar los resultados muestran que variables como el pib per cápita, la salud y el apoyo familiar son las que guardan mayor correlación con el nivel de felicidad reportado por las naciones también la libertad percibida y confianza en el gobierno tienen un impacto significativo aunque en menor medida.
# Podemos observar que los países con mayores recursos económicos y estabilidad social en su mayoría ubicados en Europa occidental y América del Norte presentan los niveles de felicidad más altos en contraste los países con menor desarrollo económico y problemas de gobernanza tienden a mostrar puntajes más bajos.
# Con todo lo anterior podemos decir que la felicidad nacional es un fenómeno multidimensional en el cual convergen tanto la prosperidad económica como la cohesión social y la calidad institucional esto sugiere que las políticas públicas orientadas únicamente al crecimiento económico No son suficientes se requiere también fomentar la equidad social el acceso a servicios básicos, la transparencia institucional y el fortalecimiento de redes comunitarias para así poder lograr un bienestar integral entre las sociedades
